# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('processed.cleveland.data')

# %%
data
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num\t
# 0      3.0  0.0  6.0      0
# 1      2.0  3.0  3.0      2
# 2      2.0  2.0  7.0      1
# 3      3.0  0.0  3.0      0
# 4      1.0  0.0  3.0      0
# ..     ...  ...  ...    ...
# 298    2.0  0.0  7.0      1
# 299    2.0  2.0  7.0      2
# 300    2.0  1.0  7.0      3
# 301    2.0  1.0  3.0      1
# 302    1.0    ?  3.0      0
#
# [303 rows x 14 columns]

# %%
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num\t
# 0    3.0  0.0  6.0      0
# 1    2.0  3.0  3.0      2
# 2    2.0  2.0  7.0      1
# 3    3.0  0.0  3.0      0
# 4    1.0  0.0  3.0      0

# %%
data.tail()
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num\t
# 298    2.0  0.0  7.0      1
# 299    2.0  2.0  7.0      2
# 300    2.0  1.0  7.0      3
# 301    2.0  1.0  3.0      1
# 302    1.0    ?  3.0      0

# %%
data.shape
# Out:
# (303, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num	      303 non-null    int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 33.3+ KB

# %%
data.describe(include='all')
# Out:
#                age         sex          cp    trestbps        chol  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     54.438944    0.679868    3.158416  131.689769  246.693069
# std       9.038662    0.467299    0.960126   17.599748   51.776918
# min      29.000000    0.000000    1.000000   94.000000  126.000000
# 25%      48.000000    0.000000    3.000000  120.000000  211.000000
# 50%      56.000000    1.000000    3.000000  130.000000  241.000000
# 75%      61.000000    1.000000    4.000000  140.000000  275.000000
# max      77.000000    1.000000    4.000000  200.000000  564.000000
#
#                fbs     restecg     thalach       exang     oldpeak  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.148515    0.990099  149.607261    0.326733    1.039604
# std       0.356198    0.994971   22.875003    0.469794    1.161075
# min       0.000000    0.000000   71.000000    0.000000    0.000000
# 25%       0.000000    0.000000  133.500000    0.000000    0.000000
# 50%       0.000000    1.000000  153.000000    0.000000    0.800000
# 75%       0.000000    2.000000  166.000000    1.000000    1.600000
# max       1.000000    2.000000  202.000000    1.000000    6.200000
#
#              slope   ca thal       num\t
# count   303.000000  303  303  303.000000
# unique         NaN    5    4         NaN
# top            NaN  0.0  3.0         NaN
# freq           NaN  176  166         NaN
# mean      1.600660  NaN  NaN    0.937294
# std       0.616226  NaN  NaN    1.228536
# min       1.000000  NaN  NaN    0.000000
# 25%       1.000000  NaN  NaN    0.000000
# 50%       2.000000  NaN  NaN    0.000000
# 75%       2.000000  NaN  NaN    2.000000
# max       3.000000  NaN  NaN    4.000000

# %%
#finding missing values
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num\t       0
# dtype: int64

# %%
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     50
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# num\t         5
# dtype: int64

# %%
print((data == '?').sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num\t       0
# dtype: int64

# %%
datas=data.rename(columns={'num\t':'target'})
datas
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  target
# 0      3.0  0.0  6.0       0
# 1      2.0  3.0  3.0       2
# 2      2.0  2.0  7.0       1
# 3      3.0  0.0  3.0       0
# 4      1.0  0.0  3.0       0
# ..     ...  ...  ...     ...
# 298    2.0  0.0  7.0       1
# 299    2.0  2.0  7.0       2
# 300    2.0  1.0  7.0       3
# 301    2.0  1.0  3.0       1
# 302    1.0    ?  3.0       0
#
# [303 rows x 14 columns]

# %%
datas['ca'].unique()
# Out:
# array(['0.0', '3.0', '2.0', '1.0', '?'], dtype=object)

# %%
datas['thal'].unique()
# Out:
# array(['6.0', '3.0', '7.0', '?'], dtype=object)

# %%
datas[(datas['ca'] == '?') | (datas['thal'] == '?')]
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 87   53.0  0.0  3.0     128.0  216.0  0.0      2.0    115.0    0.0      0.0
# 166  52.0  1.0  3.0     138.0  223.0  0.0      0.0    169.0    0.0      0.0
# 192  43.0  1.0  4.0     132.0  247.0  1.0      2.0    143.0    1.0      0.1
# 266  52.0  1.0  4.0     128.0  204.0  1.0      0.0    156.0    1.0      1.0
# 287  58.0  1.0  2.0     125.0  220.0  0.0      0.0    144.0    0.0      0.4
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  target
# 87     1.0  0.0    ?       0
# 166    1.0    ?  3.0       0
# 192    2.0    ?  7.0       1
# 266    2.0  0.0    ?       2
# 287    2.0    ?  7.0       0
# 302    1.0    ?  3.0       0

# %%
datas.replace('?', np.nan, inplace=True)

# %%
datas['thal'].unique()
# Out:
# array(['6.0', '3.0', '7.0', nan], dtype=object)

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
datas[['ca', 'thal']] = imputer.fit_transform(datas[['ca', 'thal']])

# %%
datas["ca"] = datas["ca"].astype(float).astype(int)
datas["chol"] = datas["chol"].astype(float).astype(int)
datas["age"] = datas["age"].astype(float).astype(int)
datas["sex"] = datas["sex"].astype(float).astype(int)
datas["trestbps"] = datas["trestbps"].astype(float).astype(int)
datas["cp"] = datas["cp"].astype(float).astype(int)
datas["fbs"] = datas["fbs"].astype(float).astype(int)
datas["thal"] = datas["thal"].astype(float).astype(int)
datas["restecg"] = datas["restecg"].astype(float).astype(int)
datas["thalach"] = datas["thalach"].astype(float).astype(int)
datas["exang"] = datas["exang"].astype(float).astype(int)
datas["slope"] = datas["slope"].astype(float).astype(int)

# %%
datas["target"] = datas["target"].astype(float).astype(int)

# %%
numeric_cols = datas.select_dtypes(include=['int64','float64']).columns

for col in numeric_cols:

    Q1 = datas[col].quantile(0.25)
    Q3 = datas[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = datas[(datas[col] < lower_bound) | (datas[col] > upper_bound)]

    print(f"Feature: {col}")
    print(f"Lower Bound: {lower_bound}")
    print(f"Upper Bound: {upper_bound}")
    print(f"Number of Outliers: {len(outliers)}")
    print("-"*40)
# Out:
# Feature: age
# Lower Bound: 28.5
# Upper Bound: 80.5
# Number of Outliers: 0
# ----------------------------------------
# Feature: sex
# Lower Bound: -1.5
# Upper Bound: 2.5
# Number of Outliers: 0
# ----------------------------------------
# Feature: cp
# Lower Bound: 1.5
# Upper Bound: 5.5
# Number of Outliers: 23
# ----------------------------------------
# Feature: trestbps
# Lower Bound: 90.0
# Upper Bound: 170.0
# Number of Outliers: 9
# ----------------------------------------
# Feature: chol
# Lower Bound: 115.0
# Upper Bound: 371.0
# Number of Outliers: 5
# ----------------------------------------
# Feature: fbs
# Lower Bound: 0.0
# Upper Bound: 0.0
# Number of Outliers: 45
# ----------------------------------------
# Feature: restecg
# Lower Bound: -3.0
# Upper Bound: 5.0
# Number of Outliers: 0
# ----------------------------------------
# Feature: thalach
# Lower Bound: 84.75
# Upper Bound: 214.75
# Number of Outliers: 1
# ----------------------------------------
# Feature: exang
# Lower Bound: -1.5
# Upper Bound: 2.5
# Number of Outliers: 0
# ----------------------------------------
# Feature: oldpeak
# Lower Bound: -2.4000000000000004
# Upper Bound: 4.0
# Number of Outliers: 5
# ----------------------------------------
# Feature: slope
# Lower Bound: -0.5
# Upper Bound: 3.5
# Number of Outliers: 0
# ----------------------------------------
# Feature: ca
# Lower Bound: -1.5
# Upper Bound: 2.5
# Number of Outliers: 20
# ----------------------------------------
# Feature: thal
# Lower Bound: -3.0
# Upper Bound: 13.0
# Number of Outliers: 0
# ----------------------------------------
# Feature: target
# Lower Bound: -3.0
# Upper Bound: 5.0
# Number of Outliers: 0
# ----------------------------------------

# %%
corr = datas.corr()
plt.figure(figsize=(25,10))
sns.heatmap(corr,annot=True,fmt='.2')
# Out:
# <Axes: >

# %%
datas['target'] = np.where(datas['target'] == 0, 0, 1)

# %%
datas['slope'].unique()
# Out:
# array([3, 2, 1])

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   restecg   303 non-null    int64
#  5   thalach   303 non-null    int64
#  6   exang     303 non-null    int64
#  7   oldpeak   303 non-null    float64
#  8   slope     303 non-null    int64
#  9   ca        303 non-null    int64
#  10  thal      303 non-null    int64
#  11  target    303 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 28.5 KB

# %%
sns.countplot(x='target', data=datas)
plt.title('clevland heart disease ')
plt.show()

# %%
datas.head()
# Out:
#    age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  thal  \
# 0   63    1   1       145        2      150      0      2.3      3   0     6
# 1   67    1   4       160        2      108      1      1.5      2   3     3
# 2   67    1   4       120        2      129      1      2.6      2   2     7
# 3   37    1   3       130        0      187      0      3.5      3   0     3
# 4   41    0   2       130        2      172      0      1.4      1   0     3
#
#    target
# 0       0
# 1       2
# 2       1
# 3       0
# 4       0

# %%
datas['age'].unique()
# Out:
# array([1, 2, 0])

# %%
#one hot encoding
#datas = pd.get_dummies(datas,columns=['thalach','age','trestbps','oldpeak','chol'])
#datas
# Out:
#      sex  cp  fbs  restecg  exang  slope  ca  thal  num\t  thalach_high  ...  \
# 0      1   1    1        2      0      3   0     6      0         False  ...
# 1      1   4    0        2      1      2   3     3      2         False  ...
# 2      1   4    0        2      1      2   2     7      1         False  ...
# 3      1   3    0        0      0      3   0     3      0          True  ...
# 4      0   2    0        2      0      1   0     3      0          True  ...
# ..   ...  ..  ...      ...    ...    ...  ..   ...    ...           ...  ...
# 298    1   1    0        0      0      2   0     7      1         False  ...
# 299    1   4    1        0      0      2   2     7      2         False  ...
# 300    1   4    0        0      1      2   1     7      3         False  ...
# 301    0   2    0        2      0      2   1     3      1          True  ...
# 302    1   3    0        0      0      1   0     3      0          True  ...
#
#      age_young  trestbps_mild  trestbps_moderate  trestbps_severe  \
# 0        False          False               True            False
# 1        False          False              False             True
# 2        False           True              False            False
# 3         True          False               True            False
# 4        False          False               True            False
# ..         ...            ...                ...              ...
# 298      False           True              False            False
# 299      False          False               True            False
# 300      False          False               True            False
# 301      False          False               True            False
# 302       True          False               True            False
#
#      oldpeak_mild  oldpeak_moderate  oldpeak_severe  chol_borderline  \
# 0           False              True           False             True
# 1            True             False           False            False
# 2           False              True           False             True
# 3           False             False            True            False
# 4            True             False           False             True
# ..            ...               ...             ...              ...
# 298          True             False           False            False
# 299         False             False            True            False
# 300          True             False           False            False
# 301          True             False           False             True
# 302          True             False           False            False
#
#      chol_high  chol_optimal
# 0        False         False
# 1         True         False
# 2        False         False
# 3         True         False
# 4        False         False
# ..         ...           ...
# 298       True         False
# 299      False          True
# 300      False          True
# 301      False         False
# 302      False          True
#
# [303 rows x 24 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
datas["chol"] = le.fit_transform(datas["chol"])
datas["thalach"] = le.fit_transform(datas["thalach"])
datas["oldpeak"] = le.fit_transform(datas["oldpeak"])
datas["trestbps"] = le.fit_transform(datas["trestbps"])
datas["age"] = le.fit_transform(datas["age"])

# %%
X['oldpeak'].unique()
# Out:
# array([2.3, 1.5, 2.6, 3.5, 1.4, 0.8, 3.6, 0.6, 3.1, 0.4, 1.3, 0. , 0.5,
#        1.6, 1. , 1.2, 0.2, 1.8, 3.2, 2.4, 2. , 2.5, 2.2, 2.8, 3. , 3.4,
#        6.2, 4. , 5.6, 2.9, 0.1, 2.1, 1.9, 4.2, 0.9, 1.1, 3.8, 0.7, 0.3,
#        4.4])

# %%
X = datas.drop("target",axis=1)
Y = datas["target"]
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    1
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
from sklearn.metrics import accuracy_score

train_pred = model.predict(X_train)
train_acc = accuracy_score(Y_train, train_pred)
train_acc
# Out:
# 0.9586776859504132

# %%
test_pred = model.predict(X_test)
test_acc = accuracy_score(Y_test, test_pred)
test_acc
# Out:
# 0.8852459016393442

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler on the data and transform it
scaled_data = scaler.fit_transform(X)

# %%
Y= np.squeeze(Y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.20, stratify=Y,random_state=42)
X_test_copy = X_test.copy()

# %%
# Train the Random Forest model
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=200,max_depth=6, min_samples_split=5, random_state=42)
model=rf_model.fit(X_train, Y_train)

# %%
# Make predictions on the test set
rf_predictions= rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
rf_Acc = accuracy_score(Y_test, rf_predictions)
precision = precision_score(Y_test, rf_predictions, average='weighted')
recall = recall_score(Y_test, rf_predictions, average='weighted')
f1 = f1_score(Y_test, rf_predictions, average='weighted')
conf_matrix = confusion_matrix(Y_test, rf_predictions)

print(f"rf_Acc: {rf_Acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# rf_Acc: 0.8852
# Precision: 0.8899
# Recall: 0.8852
# F1 Score: 0.8854
# Confusion Matrix:
# [[28  5]
#  [ 2 26]]

# %%
import xgboost as xgb
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, Y_train)
xgb_predictions = xgb_model.predict(X_test)

# %%
xgb_Acc = accuracy_score(Y_test, xgb_predictions)
precision = precision_score(Y_test, xgb_predictions, average='macro')
recall = recall_score(Y_test, xgb_predictions, average='macro')
f1 = f1_score(Y_test, xgb_predictions, average='macro')
conf_matrix = confusion_matrix(Y_test, xgb_predictions)
class_report = classification_report(Y_test, xgb_predictions)




print(f"xgb_Acc: {xgb_Acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{class_report}")
# Out:
# xgb_Acc: 0.8361
# Precision: 0.8453
# Recall: 0.8431
# F1 Score: 0.8360
# Confusion Matrix:
# [[25  8]
#  [ 2 26]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.83        33
#            1       0.76      0.93      0.84        28
#
#     accuracy                           0.84        61
#    macro avg       0.85      0.84      0.84        61
# weighted avg       0.85      0.84      0.84        61

# %%
from sklearn.linear_model import LogisticRegression

# Create a logistic regression model
logreg_model = LogisticRegression(max_iter=10000)

# Train the model on the training data
logreg_model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
log_predictions = logreg_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
log_Acc = accuracy_score(Y_test, log_predictions)
precision = precision_score(Y_test, log_predictions, average='weighted')
recall = recall_score(Y_test,log_predictions, average='weighted')
f1 = f1_score(Y_test, log_predictions, average='weighted')
conf_matrix = confusion_matrix(Y_test,log_predictions)

print(f"log_Acc: {log_Acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# log_Acc: 0.8525
# Precision: 0.8640
# Recall: 0.8525
# F1 Score: 0.8525
# Confusion Matrix:
# [[26  7]
#  [ 2 26]]

# %%
from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(f_classif, k=10)
X_selected = selector.fit_transform(X_scaled, Y)

# %%
from sklearn.svm import SVC

# Create an SVM model
svm_model = SVC()

# Train the model on the training data
svm_model.fit(X_train, Y_train)
# Out:
# SVC()

# %%
svm_model_predictions = svm_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
svm_Acc = accuracy_score(Y_test, svm_model_predictions)
precision = precision_score(Y_test, svm_model_predictions, average='weighted')
recall = recall_score(Y_test,svm_model_predictions, average='weighted')
f1 = f1_score(Y_test, svm_model_predictions, average='weighted')
conf_matrix = confusion_matrix(Y_test,svm_model_predictions)

print(f"svm_Acc: {svm_Acc:.2f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# svm_Acc: 0.69
# Precision: 0.6930
# Recall: 0.6885
# F1 Score: 0.6812
# Confusion Matrix:
# [[27  6]
#  [13 15]]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=1)  # You can choose the value of k (number of neighbors)
knn_model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
knn_predictions = knn_model.predict(X_test)

# %%
knn_Acc = accuracy_score(Y_test, knn_predictions)
conf_matrix = confusion_matrix(Y_test, knn_predictions)
class_report = classification_report(Y_test, knn_predictions)
f1 = f1_score(Y_test, knn_predictions, average='weighted')
recall = recall_score(Y_test,knn_predictions, average='weighted')
precision = precision_score(Y_test, knn_predictions, average='weighted')

print(f"knn_Acc: {knn_Acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{class_report}")
# Out:
# knn_Acc: 0.6557
# Precision: 0.6544
# Recall: 0.6557
# F1 Score: 0.6535
# Confusion Matrix:
# [[24  9]
#  [12 16]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70        33
#            1       0.64      0.57      0.60        28
#
#     accuracy                           0.66        61
#    macro avg       0.65      0.65      0.65        61
# weighted avg       0.65      0.66      0.65        61
